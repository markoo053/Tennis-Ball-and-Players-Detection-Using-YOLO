# %%
# !yolo val model=yolov9c.pt data=tennis_config.yaml iou=0.5 conf=0.2
# Out:
# Ultralytics 8.3.213  Python-3.13.7 torch-2.8.0+cpu CPU (Intel Core i5-10210U 1.60GHz)
# YOLOv9c summary (fused): 156 layers, 25,380,928 parameters, 0 gradients, 102.7 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 10.610.0 MB/s, size: 369.8 KB)
#
# val: Scanning D:\YOLO-TennisAnalysis\tennis_data\labels\test.cache... 107 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 107/107 12.5Mit/s 0.0s
# val: Scanning D:\YOLO-TennisAnalysis\tennis_data\labels\test.cache... 107 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 107/107 1.5Mit/s 0.0s
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 0.0it/s 28.8s<9:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 0.0it/s 45.5s<3:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 0.0it/s 59.8s<1:44
# ...
